# %%
import utils
import librosa
import librosa.display
import numpy as np
import scipy.signal as sgl
import matplotlib.pyplot as plt
from IPython.display import Audio

# %%
y, sr = librosa.load(librosa.util.example('brahms'))
# Out:
# Downloading file 'Hungarian_Dance_number_5_-_Allegro_in_F_sharp_minor_(string_orchestra).ogg' from 'https://librosa.org/data/audio/Hungarian_Dance_number_5_-_Allegro_in_F_sharp_minor_(string_orchestra).ogg' to '/home/lionel/.cache/librosa'.

# %%
Audio(data=y, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.figure(figsize=(15, 10))
librosa.display.waveplot(y, sr)

# %%
D = librosa.stft(y)

# %%
power = librosa.amplitude_to_db(np.abs(D))

plt.figure(figsize=(15, 10))
librosa.display.specshow(power, x_axis='time', y_axis='linear')
